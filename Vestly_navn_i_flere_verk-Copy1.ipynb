# %%
styles['AU']
# Out:
# <style  type="text/css" >
#     #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row0_col0 {
#             background-color:  #ffedb5;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row0_col1 {
#             background-color:  #f4a5ac;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row0_col2 {
#             background-color:  #71c6d4;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row0_col3 {
#             background-color:  #2f3a84;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row0_col4 {
#             background-color:  #fbd7c7;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row0_col5 {
#             background-color:  #65c09a;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row0_col6 {
#             background-color:  #89689e;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row1_col0 {
#             background-color:  #fff8e2;
#         }    #T_e6fec36c_616a_11ea_bb40_000acd2bfab2row1_col1 {
#             background-color:  #fbdcdf;
# ...

# %%
styles['GU']
# Out:
# <style  type="text/css" >
#     #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row0_col0 {
#             background-color:  #fffbef;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row0_col1 {
#             background-color:  #fbdcdf;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row0_col2 {
#             background-color:  #46b5c7;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row0_col3 {
#             background-color:  #d3d6ef;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row0_col4 {
#             background-color:  #fbd6c5;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row0_col5 {
#             background-color:  #a6dbc5;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row0_col6 {
#             background-color:  #9274a5;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row1_col0 {
#             background-color:  #ffedb5;
#         }    #T_e754ed1c_616a_11ea_b11e_000acd2bfab2row1_col1 {
#             background-color:  #f4a5ac;
# ...

# %%
styles['KA']
# Out:
# <style  type="text/css" >
#     #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row0_col0 {
#             background-color:  #fff5d8;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row0_col1 {
#             background-color:  #f9cfd3;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row0_col2 {
#             background-color:  #c1e6ec;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row0_col3 {
#             background-color:  #e7e9f6;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row0_col4 {
#             background-color:  #fffbf9;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row0_col5 {
#             background-color:  #47ae83;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row0_col6 {
#             background-color:  #a086b1;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row1_col0 {
#             background-color:  #fffbef;
#         }    #T_e7b48b5c_616a_11ea_86bb_000acd2bfab2row1_col1 {
#             background-color:  #fdeced;
# ...

# %%
styles['ES']
# Out:
# <style  type="text/css" >
#     #T_e81a4340_616a_11ea_967c_000acd2bfab2row0_col0 {
#             background-color:  #fffbef;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row0_col1 {
#             background-color:  #fdeced;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row0_col2 {
#             background-color:  #ebf7f9;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row0_col3 {
#             background-color:  #b4bae4;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row0_col4 {
#             background-color:  #fbd9ca;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row0_col5 {
#             background-color:  #ecf7f3;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row0_col6 {
#             background-color:  #f2eff4;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row1_col0 {
#             background-color:  #fffbef;
#         }    #T_e81a4340_616a_11ea_967c_000acd2bfab2row1_col1 {
#             background-color:  #fdeced;
# ...
