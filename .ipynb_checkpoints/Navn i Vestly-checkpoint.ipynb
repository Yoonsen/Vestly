# %% [markdown]
# Få frem gjesteopptredener. Hvordan opptrer de?

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
import dhlab.graph_networkx_louvain as gnl
import dhlab.token_map as tm
from collections import Counter
import qgrid

# %%
import pandas as pd

def alle_korpusnavn(korpus, ratio=0.3, cutoff=0):
    urner = nb.pure_urn(korpus)
    alle_navn = tm.combine_names(tm.corpus_names(urner, ratio = ratio, cutoff = cutoff))
    return alle_navn

def tell_navn(korpus, token_map):
    res = dict()
    for urn in korpus['urn']:
        res[urn] = tm.count_name_strings(str(urn), token_map).to_dict()[0]
    return pd.DataFrame(pd.DataFrame(res).sum(axis=1).sort_values(ascending=False))

# %%
fargekoder = """Guro-bøkene: R251/G213/B196 -- #FBD5C4
Kaos-bøkene: 71/173/130 -- #47AD82
Ola Aleksander-bøkene: 255/216/97 --#FFD861
Ellen Andrea og småtassene: 127/95/147 -- #7F5F93
Lillebror og Knerten: 58/172/190 -- #3AACBE
Mormor: 232/64/78 -- #E8404E
Aurora og sokrates blå: 47/58/131 – #2F3A83"""

# %%
korpus_raw = nb.book_corpus(author="vestly%anne%cath%", limit = 1000)

# %%
titles = Counter(dict(Counter(korpus_raw.title.values).most_common()))

# %% [markdown]
# urns = []
# for title in titles:
#     if titles[title]:
#         urn = list(korpus_raw[korpus_raw.title == title].sort_values(by='year', ascending = False).urn)[0]
#         urns.append(urn)

# %%
urns = nb.pure_urn("""https://urn.nb.no/URN:NBN:no-nb_digibok_2014031108251
https://urn.nb.no/URN:NBN:no-nb_digibok_2015070708013
https://urn.nb.no/URN:NBN:no-nb_digibok_2010110906072
https://urn.nb.no/URN:NBN:no-nb_digibok_2010070605087




https://urn.nb.no/URN:NBN:no-nb_digibok_2014111708080
https://urn.nb.no/URN:NBN:no-nb_digibok_2018061207028
https://urn.nb.no/URN:NBN:no-nb_digibok_2018072607262
https://urn.nb.no/URN:NBN:no-nb_digibok_2008093000058
https://urn.nb.no/URN:NBN:no-nb_digibok_2009041404081

https://urn.nb.no/URN:NBN:no-nb_digibok_2012091408165
https://urn.nb.no/URN:NBN:no-nb_digibok_2009021000094



https://urn.nb.no/URN:NBN:no-nb_digibok_2015010808013
https://urn.nb.no/URN:NBN:no-nb_digibok_2017053048056
https://urn.nb.no/URN:NBN:no-nb_digibok_2013061708033
https://urn.nb.no/URN:NBN:no-nb_digibok_2014013106097
https://urn.nb.no/URN:NBN:no-nb_digibok_2008052804024
https://urn.nb.no/URN:NBN:no-nb_digibok_2007071100044

https://urn.nb.no/URN:NBN:no-nb_digibok_2010120820039
https://urn.nb.no/URN:NBN:no-nb_digibok_2008103104089



https://urn.nb.no/URN:NBN:no-nb_digibok_2014013106098
https://urn.nb.no/URN:NBN:no-nb_digibok_2011031005056
https://urn.nb.no/URN:NBN:no-nb_digibok_2015042306048

https://urn.nb.no/URN:NBN:no-nb_digibok_2009011200085
https://urn.nb.no/URN:NBN:no-nb_digibok_2007072301006
https://urn.nb.no/URN:NBN:no-nb_digibok_2007072004008



https://urn.nb.no/URN:NBN:no-nb_digibok_2012121106015
https://urn.nb.no/URN:NBN:no-nb_digibok_2007060104052
https://urn.nb.no/URN:NBN:no-nb_digibok_2008102200042
https://urn.nb.no/URN:NBN:no-nb_digibok_2007062101032
https://urn.nb.no/URN:NBN:no-nb_digibok_2012111406308
https://urn.nb.no/URN:NBN:no-nb_digibok_2007070501032
https://urn.nb.no/URN:NBN:no-nb_digibok_2007070500007



https://urn.nb.no/URN:NBN:no-nb_digibok_2012092106162
https://urn.nb.no/URN:NBN:no-nb_digibok_2013011806050
https://urn.nb.no/URN:NBN:no-nb_digibok_2009042200010
https://urn.nb.no/URN:NBN:no-nb_digibok_2013102906120
https://urn.nb.no/URN:NBN:no-nb_digibok_2012091705071



https://urn.nb.no/URN:NBN:no-nb_digibok_2008062304037
https://urn.nb.no/URN:NBN:no-nb_digibok_2013100805023
https://urn.nb.no/URN:NBN:no-nb_digibok_2013100305183
https://urn.nb.no/URN:NBN:no-nb_digibok_2010052003065
https://urn.nb.no/URN:NBN:no-nb_digibok_2010043003036



https://urn.nb.no/URN:NBN:no-nb_digibok_2008102100068
https://urn.nb.no/URN:NBN:no-nb_digibok_2011060106049
https://urn.nb.no/URN:NBN:no-nb_digibok_2014081905070""")

# %%
korpus = nb.frame(nb.metadata(urns), "urn author year title subtitle publisher genre sesam lang trans".split())

# %%
korpus
# Out:
#               urn              author  year  \
# 0   2014031108251  Vestly, Anne-Cath.  1994
# 1   2015070708013  Vestly, Anne-Cath.  1979
# 2   2010110906072  Vestly, Anne-Cath.  1955
# 3   2010070605087  Vestly, Anne-Cath.  1956
# 4   2014111708080  Vestly, Anne-Cath.  1994
# 5   2008093000058  Vestly, Anne-Cath.  1999
# 6   2009041404081  Vestly, Anne-Cath.  1998
# 7   2012091408165  Vestly, Anne-Cath.  1986
# 8   2009021000094  Vestly, Anne-Cath.  1999
# 9   2015010808013  Vestly, Anne-Cath.  1990
# 10  2013061708033  Vestly, Anne-Cath.  1964
# 11  2014013106097  Vestly, Anne-Cath.  1965
# 12  2008052804024  Vestly, Anne-Cath.  1973
# 13  2007071100044  Vestly, Anne-Cath.  1974
# 14  2010120820039  Vestly, Anne-Cath.  1999
# 15  2008103104089  Vestly, Anne-Cath.  2001
# 16  2014013106098  Vestly, Anne-Cath.  1989
# 17  2011031005056  Vestly, Anne-Cath.  2000
# 18  2015042306048  Vestly, Anne-Cath.  1993
# 19  2009011200085  Vestly, Anne-Cath.  1997
# 20  2007072301006  Vestly, Anne-Cath.  1971
# 21  2007072004008  Vestly, Anne-Cath.  1972
# 22  2012121106015  Vestly, Anne-Cath.  1975
# 23  2007060104052  Vestly, Anne-Cath.  1976
# 24  2008102200042  Vestly, Anne-Cath.  2000
# 25  2007062101032  Vestly, Anne-Cath.  1978
# 26  2012111406308  Vestly, Anne-Cath.  1979
# 27  2007070501032  Vestly, Anne-Cath.  1980
# 28  2007070500007  Vestly, Anne-Cath.  1981
# 29  2012092106162  Vestly, Anne-Cath.  1982
# 30  2013011806050  Vestly, Anne-Cath.  1983
# 31  2009042200010  Vestly, Anne-Cath.  1984
# 32  2013102906120  Vestly, Anne-Cath.  1985
# 33  2012091705071  Vestly, Anne-Cath.  1987
# 34  2008062304037  Vestly, Anne-Cath.  1992
# 35  2013100805023  Vestly, Anne-Cath.  1993
# 36  2013100305183  Vestly, Anne-Cath.  1994
# 37  2010052003065  Vestly, Anne-Cath.  1995
# 38  2010043003036  Vestly, Anne-Cath.  1996
# 39  2008102100068  Vestly, Anne-Cath.  2000
# 40  2011060106049  Vestly, Anne-Cath.  2002
# 41  2014081905070  Vestly, Anne-Cath.  2004
#
#                                                 title subtitle  \
# 0                      Ole Aleksander Filibom-bom-bom
# 1                            Ole Aleksander på farten
# 2                          Ole Aleksander får skjorte
# 3                 Ole Aleksander og bestemor til værs
# 4                   Åtte små, to store og en lastebil
# 5                                liten takk fra Anton
# 6                            Mormor og de åtte ungene
# 7     Mormor og de åtte ungene på sykkeltur i Danmark
# 8                       Morten og mormor og Stormvind
# 9                                Lillebror og Knerten
# 10                                 Knerten gifter seg
# 11                                   Knerten i Bessby
# 12                       Knerten og forundringspakken
# 13                               Knerten på sykkeltur
# 14      Knerten detektiv og handelsreisende Lillebror
# 15                                 Knerten politimann
# 16                                   Aurora i blokk Z
# 17                                    Aurora og pappa
# 18  Aurora og den vesle blå bilen ; Aurora og Sokr...
# 19                                   Aurora i Holland
# 20                              Aurora på hurtigruten
# 21                                Aurora fra Fabelvik
# 22                                               Guro
# 23                                Guro og nøkkerosene
# 24                                  Guro alene hjemme
# 25                                   Guro og fiolinen
# 26                                Guro og Lille-Bjørn
# 27                               Guro på Tirilltoppen
# 28                        Guro og Frydefoniorkesteret
# 29                                    Kaos og Bjørnar
# 30                              Lilla Olaug og Lubben
# 31                     Kaosgutten i Vetleby og verden
# 32                                  Kaos førskolegutt
# 33                              Kaos og hemmeligheten
# 34                             Ellen Andrea og mormor
# 35            Forundringspakken og Lagertha rasebasse
# 36                                         5 på reise
# 37                         Kostemarsj på Tirilltoppen
# 38                          Mormor og én til hos Rosa
# 39           Småtassene og andre folk på Tirilltoppen
# 40                                      Monrad tenker
# 41               Monrad og mormor i den store klubben
#
#                                             publisher       genre  \
# 0                                               Tiden     fiction
# 1                                               Tiden       novel
# 2                                               Tiden  notfiction
# 3                                               Tiden     fiction
# 4                                               Tiden     fiction
# 5                                     Gyldendal Tiden     fiction
# 6   Gyldendal Tiden;Oslo : Gyldendal Tiden, cop. 1998     fiction
# 7                                               Tiden     fiction
# 8                                     Gyldendal Tiden     fiction
# 9   Bokklubbens barn;[Stabekk] : Bokklubbens barn,...     fiction
# 10                                              Tiden     unknown
# 11                                              Tiden     fiction
# 12                                              Tiden     fiction
# 13                                              Tiden     unknown
# 14                                   Bokklubbens barn     fiction
# 15                                    Gyldendal Tiden     fiction
# 16                                              Tiden     fiction
# 17                                    Gyldendal Tiden     unknown
# 18  Bokklubbens barn;[Stabekk] : Bokklubbens barn,...     fiction
# 19                                    Gyldendal Tiden       novel
# 20                                              Tiden     fiction
# 21                                              Tiden       novel
# 22                                 Tiden;Emil Moestue     fiction
# 23                                              Tiden     fiction
# 24                                    Gyldendal Tiden     fiction
# 25                                              Tiden     fiction
# 26                                              Tiden     fiction
# 27                                              Tiden  notfiction
# 28                                              Tiden     fiction
# 29                                              Tiden  notfiction
# 30                                              Tiden     fiction
# 31                                              Tiden     fiction
# 32                                              Tiden     fiction
# 33                                              Tiden     fiction
# 34                                              Tiden     fiction
# 35                                              Tiden     fiction
# 36                                              Tiden     fiction
# 37                                              Tiden     fiction
# 38                                              Tiden     fiction
# 39                                    Gyldendal Tiden       novel
# 40                                    Gyldendal Tiden     fiction
# 41                                          Gyldendal     fiction
#
#                                sesam lang trans
# 0   a129a1b3431a53c3f3603e6556c10758  nob
# 1   04d824e5dd1785f02263f81b442e5ad8  nob
# 2   08a71482eeaad0c1a4c2476835e0ce9f  nob
# 3   229d494021e1f6803ca6b5d662fa5c75  nob
# 4   3bddefb6c44d7711d15b6969ede5e647  nob
# 5   a5501331ec8defd776da07b68235e117  nob
# 6   749d368f193c900df832d1090466864e  nob
# 7   37c89c73491546d434af07314cb1e060  nob
# 8   8eb66804535d7ec973b66c1169f5bbff  nob
# 9   c871a19b13d399950656aefd61fcc5c7  nob
# 10  514efeb8216727e7030f5055b3ed4442  nob
# 11  71f9e69c5af0d8f59403b3bcf391f9d9  nob
# 12  0dce2b30cebec852faf4d0f7ef29879d  nob
# 13  0b5945bc28ef006d1f4336332e15025e  nob
# 14  53a5f3b395d307ab8d4a7d684266e1f1  nob
# 15  577054ac7f668466368d663c9b3f90fa  nob
# 16  a7f2519cc5d1f7680db7227d006da276  nob
# 17  c7be468a2219b3f780326474196977f4  nob
# 18  3e985b1b5d115ba3ce228137c3651db3  nob
# 19  0110410395e479fc6dc7689807f5fd2c  nob
# 20  357c31f939f9602c0a30161fd4c5c3da  nob
# 21  1bcbb144164b0a03925be535e4581db4  nob
# 22  ae4c4f1b0b6617df4cfd56a7b469ad5e  nob
# 23  29bcf322e84c698b82217fe32daad26c  nob
# 24  3a61dd7117418ab26e4141dbc81de24c  nob
# 25  c3a7c71b26fb5099d5c51c612c7656a4  nob
# 26  a19651304f787d7c22f9fb83dcc1a3eb  nob
# 27  b31c216e3579d63efa915c68120c9b96  nob
# 28  61788e2b0bd926c9a75a672b34fd9d71  nob
# 29  268458077d20de750c721d1e1693256f  nob
# 30  1a298cd584af64e4fb7d806ae837026c  nob
# 31  e4eb565db563a2c21f71e42eb2e05bfa  nob
# 32  a882dbd20615919f7f25d3379d7098bc  nob
# 33  d4dd243b44de51c69ff7575feea346e0  nob
# 34  e168e67da38ab9550685b154184cfd22  nob
# 35  df05f5f51348b212e7c874288f845a8a  nob
# 36  34d4bdc194128681d94e4f7cd175bad1  nob
# 37  f00abf11b1ea3aef2dd99e9a85240ba9  nob
# 38  25b9688b3a0d699e56466b80f675e88f  nob
# 39  8a07a7ad1f9d05abfc6547fd45dbe531  nob
# 40  b8cd739a3e36ba104c72fd7cbf47072d  nob
# 41  9aa0c9fba25f4671fc8dfc01c58cf107  nob

# %%
navn = alle_korpusnavn(korpus,ratio=0.2, cutoff=10)

# %% [markdown]
# # Single navn fra bøkene

# %%
single_navn = list(navn[0].keys())

# %%
single_navn[:10]
# Out:
# ['Aleksander',
#  'Er',
#  'Filibom-bom-',
#  'Ja',
#  'Mons',
#  'Nei',
#  'Ole',
#  'Puffen',
#  'Skal',
#  'Aleksander,']

# %% [markdown]
# # Navn fra Anne Kristins excelfil

# %%
vestlys_verden = pd.read_excel("Vestlys verden.xlsx", header=None )

# %%
vestlys_v = qgrid.show_grid(vestlys_verden.fillna(''))
vestlys_v
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
a = vestlys_v.get_changed_df()

# %%
navnene = [x.split()[0] for x in list(a[1]) if x != '']

# %%
navnene
# Out:
# ['Ole',
#  'mor',
#  'far',
#  'bestefar',
#  'bestemor',
#  'Mons',
#  'Puffen',
#  'Ida',
#  'Tante',
#  'Bitteliten',
#  'ingen',
#  'Oliver',
#  'ingen',
#  'mor',
#  'far',
#  'Maren',
#  'Martin',
#  'Marte',
#  'Mads',
#  'Mona',
#  'Milly',
#  'Mina',
#  'Morten',
#  'mormor',
#  'Hulda',
#  'Henrik',
#  'tante',
#  'den',
#  'den',
#  'Ovnsrøret',
#  'mormor',
#  'Mads',
#  '5',
#  'Anne',
#  'Lars',
#  'Anton',
#  'Anne-Ophelia',
#  "Go'Rosa",
#  'Mormors',
#  'ingen',
#  'Rosa',
#  'Georg',
#  'Ole',
#  'Lillebror',
#  'Storebror',
#  'mor',
#  'far',
#  'Knerten',
#  'snekkeren',
#  'Prinsessen/Vesla',
#  'faren',
#  'tante',
#  'ingen',
#  'Karoline',
#  'Lille-Knerten',
#  'Lille-Bjørn',
#  'Tyven',
#  'Magnus',
#  'bestefar',
#  'moren',
#  'Tilla',
#  'Konstance',
#  'Ivar',
#  'Forundringspakken',
#  'Lillemamma',
#  'treffer',
#  'Aurora',
#  'Sokrates',
#  'Edvard',
#  'Marie',
#  'Knut',
#  'Nusse',
#  'Britt-Karen',
#  "mamma'n",
#  'mormor',
#  'pike',
#  'Bestefarmor',
#  'onkel',
#  'besøk',
#  'Veslestuten',
#  'Putten',
#  'Lillebror',
#  'mormor',
#  'Anette',
#  'mormors',
#  'Frøken',
#  'Valdemar',
#  'Bare',
#  'Sorenskriveren',
#  'Sorenskriverdamen',
#  'Johanna',
#  'Rakel',
#  'mormors',
#  'Onkel',
#  'Nusse',
#  'Knut',
#  'Ginneken',
#  'Froa',
#  'Guro',
#  'Erle,',
#  'Kjenner',
#  'Tullemor',
#  'Lillen',
#  'Gamle',
#  'Britt-Karen',
#  'Vaktmester',
#  'Personligheten',
#  'mormor',
#  'Nusse',
#  "mamma'n",
#  'Knut',
#  'Aurora',
#  'Nils',
#  'Edvard',
#  'Marie',
#  'Lille-Bjørn',
#  'Tullemor',
#  'Julefeiring:',
#  'Bestefar',
#  'Tullemor',
#  'Ole',
#  'Allan,',
#  'Erle',
#  'Moren',
#  'Kåre',
#  'Ny',
#  'Sykepleier',
#  'Pike',
#  'Ellen',
#  "Go'Rosa",
#  'Aurora',
#  'Kaos',
#  'Far',
#  'Mor',
#  'Eva',
#  'Bjørnar',
#  'Faster',
#  'Fastermann',
#  'Lilla',
#  'Lubben',
#  'Bjarne',
#  'Gammelbudeia',
#  'Mor',
#  'Tullemor',
#  'Bestefar',
#  'Tirilltoppen',
#  'mormor',
#  'Mormor',
#  'Ellen',
#  'Lagertha',
#  'Pappa',
#  'Sirimamma',
#  'Marte',
#  'Guro',
#  'Lille-Bjørn',
#  'Erle',
#  'Bjørn',
#  'Sokrates',
#  'mormor',
#  'Lillebror',
#  'Knerten',
#  'Tilla',
#  'Konstance',
#  'De',
#  'Allan',
#  'Tullemor',
#  'Bestefar',
#  'Aurora',
#  'Nusse',
#  'Bestemor',
#  'Bestefar',
#  'Lillebror',
#  'Tilla',
#  'Konstance',
#  'Magnus',
#  'Bestefaren',
#  'Ivar',
#  'Knerten',
#  'Karoline',
#  'Lille-Knerten',
#  'Leo',
#  'Leo',
#  'Kjartan',
#  'Bjørnar',
#  'Kaos',
#  'Rosa',
#  'Geir',
#  'Mormors',
#  'Chris,',
#  'Amund',
#  'Tore',
#  'Leo',
#  'Kjartan',
#  'Lagertha',
#  'Billy',
#  'Leander',
#  'Maren',
#  'George',
#  'Rosa',
#  'Monrad',
#  'Geir',
#  'Erling']

# %%
navnene_redigert = list(set(['Ole',
 'mor',
 'far',
 'bestefar',
 'bestemor',
 'Mons',
 'Puffen',
 'Ida',
 'Tante',
 'Bitteliten',
 'ingen',
 'Oliver',
 'ingen',
 'mor',
 'far',
 'Maren',
 'Martin',
 'Marte',
 'Mads',
 'Mona',
 'Milly',
 'Mina',
 'Morten',
 'mormor',
 'Hulda',
 'Henrik',
 'Ovnsrøret',
 'mormor',
 'Mads',
 'Anne',
 'Lars',
 'Anton',
 'Anne-Ophelia',
 "Go'Rosa",
 'Mormors',
 'ingen',
 'Rosa',
 'Georg',
 'Ole',
 'Lillebror',
 'Storebror',
 'mor',
 'far',
 'Knerten',
 'snekkeren',
 'Prinsessen/Vesla',
 'faren',
 'tante',
 'Karoline',
 'Lille-Knerten',
 'Lille-Bjørn',
 'Tyven',
 'Magnus',
 'bestefar',
 'moren',
 'Tilla',
 'Konstance',
 'Ivar',
 'Forundringspakken',
 'Lillemamma',
 'Aurora',
 'Sokrates',
 'Edvard',
 'Marie',
 'Knut',
 'Nusse',
 'Britt-Karen',
 "mamma'n",
 'mormor',
 'pike',
 'Bestefarmor',
 'onkel',
 'besøk',
 'Veslestuten',
 'Putten',
 'Lillebror',
 'mormor',
 'Anette',
 'mormors',
 'Frøken',
 'Valdemar',
 'Sorenskriveren',
 'Sorenskriverdamen',
 'Johanna',
 'Rakel',
 'mormors',
 'Onkel',
 'Nusse',
 'Knut',
 'Ginneken',
 'Froa',
 'Guro',
 'Erle,',
 'Kjenner',
 'Tullemor',
 'Lillen',
 'Gamle',
 'Britt-Karen',
 'Vaktmester',
 'Personligheten',
 'mormor',
 'Nusse',
 "mamma'n",
 'Knut',
 'Aurora',
 'Nils',
 'Edvard',
 'Marie',
 'Lille-Bjørn',
 'Tullemor',
 'Julefeiring:',
 'Bestefar',
 'Tullemor',
 'Ole',
 'Allan,',
 'Erle',
 'Moren',
 'Kåre',
 'Sykepleier',
 'Pike',
 'Ellen',
 "Go'Rosa",
 'Aurora',
 'Kaos',
 'Far',
 'Mor',
 'Eva',
 'Bjørnar',
 'Faster',
 'Fastermann',
 'Lilla',
 'Lubben',
 'Bjarne',
 'Gammelbudeia',
 'Mor',
 'Tullemor',
 'Bestefar',
 'Tirilltoppen',
 'mormor',
 'Mormor',
 'Ellen',
 'Lagertha',
 'Pappa',
 'Sirimamma',
 'Marte',
 'Guro',
 'Lille-Bjørn',
 'Erle',
 'Bjørn',
 'Sokrates',
 'mormor',
 'Lillebror',
 'Knerten',
 'Tilla',
 'Konstance',
 'Allan',
 'Tullemor',
 'Bestefar',
 'Aurora',
 'Nusse',
 'Bestemor',
 'Bestefar',
 'Lillebror',
 'Tilla',
 'Konstance',
 'Magnus',
 'Bestefaren',
 'Ivar',
 'Knerten',
 'Karoline',
 'Lille-Knerten',
 'Leo',
 'Leo',
 'Kjartan',
 'Bjørnar',
 'Kaos',
 'Rosa',
 'Geir',
 'Mormors',
 'Chris,',
 'Amund',
 'Tore',
 'Leo',
 'Kjartan',
 'Lagertha',
 'Billy',
 'Leander',
 'Maren',
 'George',
 'Rosa',
 'Monrad',
 'Geir',
 'Erling']))

# %%
ac_navn = list(set([x for x in list(a[1]) if x != '']))

# %%
ac_navn[:10]
# Out:
# ['Faster',
#  'Geir (mormors ungdomskjæreste og far til moren til de åtte ungene)',
#  'Lille-Knerten (sønn)',
#  'mormor og onkel Brande er dagmamma/dagpappa',
#  'Karoline (Knertens hustru)',
#  'Allan, spillelærer',
#  'Sirimamma / Lillemamma',
#  'onkel Brande',
#  'Frøken van Ginneken',
#  'Mina']

# %% [markdown]
# Sjekk hva som er felles:

# %%
[x for x in ac_navn if x in single_navn]
# Out:
# ['Mina',
#  'Erle',
#  'Guro',
#  'Kjartan',
#  'Amund',
#  'Marie',
#  'Knerten',
#  'Marte',
#  'Sokrates',
#  'Johanna',
#  'Tore',
#  'Mads',
#  'Maren',
#  'Hulda',
#  'Henrik',
#  'Rosa',
#  'Milly',
#  'Konstance',
#  'Rakel',
#  'Mona',
#  'Knut',
#  'Magnus',
#  'Allan',
#  'Kaos',
#  'Tullemor',
#  'Martin',
#  'Lille-Bjørn',
#  'Nusse',
#  'Lillebror',
#  'Ida',
#  'George',
#  'Aurora',
#  'Ginneken',
#  'Lillemamma',
#  'Oliver',
#  'Monrad',
#  'Lagertha',
#  'Ivar',
#  'Bjørnar',
#  'Lille-Knerten',
#  'Bjørn',
#  'Tilla',
#  'Mons',
#  'Lillen',
#  'Leo',
#  'Edvard',
#  'Karoline']

# %%
import requests

def mng(urn, wordbag, cutoff=0):
    r = requests.post("https://api.nb.no/ngram/graph", json={'urn':urn, 'words':wordbag})
    return r.json()

# %%
mng(str(korpus.urn[0]), navnene_redigert[:2])
# Out:
# []

# %%
len(navnene_redigert)
# Out:
# 124

# %%
nr = [str(x.strip()) for x in navnene_redigert]

# %%
nr_Rosa = [x for x in nr if x != 'Rosa']

# %%
"Rosa" in nr_Rosa
# Out:
# False

# %%
wG = nb.make_graph('snill trist leit stygg pen kjekk'.split())

# %%
gnl.show_graph(wG)

# %%
len([x for x in wG.nodes()])
# Out:
# 153

# %%
ordliste = """kjekk pen vakker stygg ung gammel sprek""".split()

# %%
name_graphs = []
for urn in korpus.urn:
    #print(urn)
    try:
        name_graphs.append(nb.make_network_graph(str(urn),[x for x in wG.nodes()]))
    except:
        print('galt')

# %%
import networkx as nx

# %%
totg = nx.Graph([x for g in name_graphs for x in g.edges(data=True) if x[2]['weight'] > 0])

# %%
totg.edges()
# Out:
# EdgeView([('flink', 'glad'), ('flink', 'frisk'), ('flink', 'god'), ('flink', 'stolt'), ('flink', 'kjekk'), ('flink', 'Stille'), ('flink', 'travelt'), ('flink', 'hyggelig'), ('flink', 'fornøyd'), ('flink', 'ring'), ('flink', 'snill'), ('flink', 'varm'), ('flink', 'blid'), ('flink', 'rolig'), ('flink', 'søt'), ('flink', 'klok'), ('flink', 'suiten'), ('flink', 'sikker'), ('flink', 'opplagt'), ('flink', 'pen'), ('glad', 'opplagt'), ('glad', 'sikker'), ('glad', 'snill'), ('glad', 'tam'), ('glad', 'frisk'), ('glad', 'god'), ('glad', 'fornøyd'), ('glad', 'hyggelig'), ('glad', 'ring'), ('glad', 'rolig'), ('glad', 'stolt'), ('glad', 'suiten'), ('glad', 'travelt'), ('glad', 'varm'), ('glad', 'klok'), ('glad', 'trygg'), ('glad', 'vennlig'), ('glad', 'blid'), ('glad', 'ung'), ('glad', 'søt'), ('glad', 'trofast'), ('glad', 'grei'), ('opplagt', 'hyggelig'), ('opplagt', 'blid'), ('opplagt', 'god'), ('god', 'hyggelig'), ('god', 'ryddig'), ('god', 'travelt'), ('god', 'varm'), ('god', 'sikker'), ('god', 'pen'), ('god', 'stolt'), ('god', 'kjekk'), ('god', 'grei'), ('god', 'snill'), ('god', 'apen'), ('god', 'rolig'), ('god', 'vennlig'), ('god', 'rask'), ('god', 'renslig'), ('god', 'frisk'), ('god', 'trivelig'), ('god', 'fornøyd'), ('god', 'leken'), ('god', 'blid'), ('god', 'suiten'), ('god', 'trygg'), ('hyggelig', 'blid'), ('hyggelig', 'travelt'), ('hyggelig', 'rolig'), ('hyggelig', 'pen'), ('hyggelig', 'sikker'), ('hyggelig', 'frisk'), ('hyggelig', 'fornøyd'), ('hyggelig', 'vennlig'), ('hyggelig', 'suiten'), ('hyggelig', 'morsom'), ('hyggelig', 'grei'), ('hyggelig', 'stolt'), ('blid', 'fornøyd'), ('blid', 'smilende'), ('blid', 'ung'), ('blid', 'stolt'), ('blid', 'sur'), ('blid', 'morsom'), ('blid', 'varm'), ('blid', 'ring'), ('blid', 'rolig'), ('blid', 'travelt'), ('blid', 'sikker'), ('blid', 'suiten'), ('fornøyd', 'stolt'), ('fornøyd', 'varm'), ('fornøyd', 'kjekk'), ('fornøyd', 'sikker'), ('fornøyd', 'trygg'), ('fornøyd', 'rolig'), ('fornøyd', 'leken'), ('fornøyd', 'sur'), ('sikker', 'rolig'), ('sikker', 'Stille'), ('sikker', 'snill'), ('sikker', 'stolt'), ('sikker', 'travelt'), ('sikker', 'klok'), ('sikker', 'ung'), ('sikker', 'suiten'), ('sikker', 'trygg'), ('snill', 'suiten'), ('snill', 'frisk'), ('snill', 'tålmodig'), ('snill', 'rolig'), ('snill', 'vennlig'), ('snill', 'travelt'), ('snill', 'søt'), ('snill', 'pen'), ('snill', 'rask'), ('snill', 'trygg'), ('suiten', 'trygg'), ('suiten', 'varm'), ('suiten', 'rolig'), ('suiten', 'travelt'), ('kjekk', 'trygg'), ('kjekk', 'varm'), ('kjekk', 'frisk'), ('kjekk', 'ung'), ('kjekk', 'stolt'), ('trygg', 'varm'), ('trygg', 'pen'), ('frisk', 'travelt'), ('frisk', 'ung'), ('frisk', 'sunn'), ('stolt', 'rolig'), ('stolt', 'apen'), ('stolt', 'pen'), ('stolt', 'ung'), ('travelt', 'rolig'), ('travelt', 'morsom'), ('varm', 'leken'), ('varm', 'rolig'), ('rolig', 'leken'), ('rolig', 'Rolig'), ('rolig', 'ung'), ('rolig', 'jevn'), ('rolig', 'trivelig'), ('rolig', 'grei'), ('pen', 'ung'), ('pen', 'grei'), ('smilende', 'ung'), ('ung', 'søt'), ('ring', 'morsom'), ('ring', 'trivelig'), ('sur', 'søt'), ('Rask', 'rask')])

# %%
gnl.show_graph(totg, spread=0.8)

# %%
gnl.show_communities(totg)
# Out:
# fornøyd-blid :  fornøyd, blid
#
# glad-snill :  glad, snill, flink, opplagt
#
# god-rolig :  god, rolig, hyggelig
